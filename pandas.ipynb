# %%
pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.9 MB 1.9 MB/s eta 0:00:06
#    ---------------------------------------- 0.0/9.9 MB 1.9 MB/s eta 0:00:06
#    ---------------------------------------- 0.0/9.9 MB 1.9 MB/s eta 0:00:06
# ...

# %%
import pandas as pd

# %%
data={'Name' : ['Alice','Bob','Martha','Adam'],
       'Age' : [25,26,23,24],}
df = pd.DataFrame(data)
print(data)
# Out:
# {'Name': ['Alice', 'Bob', 'Martha', 'Adam'], 'Age': [25, 26, 23, 24]}

# %%
datalist=[['Alice',25],['Bob',26]]
df=pd.DataFrame(datalist,columns=['Name','Age'])

# %%
df.head()
# Out:
#      Name  Age
# 0   Alice   25
# 1     Bob   26
# 2  Martha   23
# 3    Adam   24

# %%
df.tail()
# Out:
#      Name  Age
# 0   Alice   25
# 1     Bob   26
# 2  Martha   23
# 3    Adam   24

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    4 non-null      str
#  1   Age     4 non-null      int64
# dtypes: int64(1), str(1)
# memory usage: 196.0 bytes

# %%
df.describe()
# Out:
#              Age
# count   4.000000
# mean   24.500000
# std     1.290994
# min    23.000000
# 25%    23.750000
# 50%    24.500000
# 75%    25.250000
# max    26.000000

# %%
df['Name']
# Out:
# 0     Alice
# 1       Bob
# 2    Martha
# 3      Adam
# Name: Name, dtype: str

# %%
df['Age']
# Out:
# 0    25
# 1    26
# 2    23
# 3    24
# Name: Age, dtype: int64

# %%
df.loc[2]
# Out:
# Name    Martha
# Age         23
# Name: 2, dtype: object

# %%
df.iloc[1]
# Out:
# Name    Bob
# Age      26
# Name: 1, dtype: object

# %%
df[df['Age']>23]
# Out:
#     Name  Age
# 0  Alice   25
# 1    Bob   26
# 3   Adam   24

# %%
df['Gender'] = ['F','M','F','M']

# %%
df.drop('Age',axis=1,inplace=True)

# %%
df.isnull()
# Out:
#     Name
# 0  False
# 1  False
# 2  False
# 3  False

# %%
df.dropna()
# Out:
#      Name
# 0   Alice
# 1     Bob
# 2  Martha
# 3    Adam

# %%
df.fillna(0)
# Out:
#      Name
# 0   Alice
# 1     Bob
# 2  Martha
# 3    Adam

# %%
df.groupby('Gender')['Age'].mean()
# Out:
# Gender
# F    24.0
# M    25.0
# Name: Age, dtype: float64

# %%
df1=pd.DataFrame({'key':[1,2,3],
                 'Name':['Max','Jonas','Noah']})

df2=pd.DataFrame({'key':[1,2,3],
                 'Name':['Susan','Peggy','Agnes']})
pd.merge(df1,df2,on='key')
# Out:
#    key Name_x Name_y
# 0    1    Max  Susan
# 1    2  Jonas  Peggy
# 2    3   Noah  Agnes

# %%
df1=pd.DataFrame({'key':[1,2,3],
                 'Name':['Max','Jonas','Noah']})

df2=pd.DataFrame({'Stream':['CSE','ECE','EEE'],
                 'Type':['Part time','Full time','Hybrid']})
df1.join(df2)
# Out:
#    key   Name Stream       Type
# 0    1    Max    CSE  Part time
# 1    2  Jonas    ECE  Full time
# 2    3   Noah    EEE     Hybrid

# %%
open('data.csv','w').close()

# %%
df.to_csv('data.csv', index = False)

# %%
df=pd.read_csv('data.csv')

# %%
open('output.csv','w').close()

# %%
df.to_csv('output.csv',index=False)

# %%
print(df)
# Out:
#      Name  Age Gender
# 0   Alice   25      F
# 1     Bob   26      M
# 2  Martha   23      F
# 3    Adam   24      M

# %%
df.sort_values('Age')
# Out:
#      Name  Age Gender
# 2  Martha   23      F
# 3    Adam   24      M
# 0   Alice   25      F
# 1     Bob   26      M

# %%
df['Age'].apply(lambda x:x+1)
# Out:
# 0    26
# 1    27
# 2    24
# 3    25
# Name: Age, dtype: int64

# %%
df['Name'].unique()
# Out:
# <StringArray>
# ['Alice', 'Bob', 'Martha', 'Adam']
# Length: 4, dtype: str

# %%
df['Age'].value_counts()
# Out:
# Age
# 25    1
# 26    1
# 23    1
# 24    1
# Name: count, dtype: int64
